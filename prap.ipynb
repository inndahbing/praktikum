# %%
"halo dunia" #string
'halo dunia'
# Out:
# 'halo dunia'

# %%
print ("hallo dunia")
# Out:
# hallo dunia

# %%
print ("hallo dunia")
# Out:
# hallo dunia

# %%
print (1+1)
# Out:
# 2

# %%
print (1*1)
# Out:
# 1

# %%
"""
print (1-2)
print (1-2)
print (1-2)
"""
print (1-2)
# Out:
# -1

# %%
print (2/1)
# Out:
# 2.0
