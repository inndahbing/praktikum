# %% [markdown]
# <a href="https://colab.research.google.com/github/inndahbing/praktikum/blob/main/identitas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Menampilkan judul program
print("DATA DIRI MAHASISWA")

# Menampilkan nama mahasiswa
print("Nama : Indah Cahya Murti")

# Menampilkan NIM mahasiswa
print("NIM : 2605060020")

# Menampilkan tempat dan tanggal lahir
print("Tempat, Tanggal Lahir : Magelang, 06 Februari 2009")

# Menampilkan alamat
print("Alamat : Magelang, Jawa Tengah")

# Menampilkan jenis kelamin
print("Jenis Kelamin : Perempuan")

# Menampilkan hobi
print("Hobi : Berenang,desain dan coding ")
# Out:
# DATA DIRI MAHASISWA
# Nama : Indah Cahya Murti
# NIM : 2605060020
# Tempat, Tanggal Lahir : Magelang, 06 Februari 2009
# Alamat : Magelang, Jawa Tengah
# Jenis Kelamin : Perempuan
# Hobi : Berenang,desain dan coding
